# %% [markdown]
# From: https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/tutorials/word2vec/word2vec_basic.py

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

import sklearn
import matplotlib
# %matplotlib inline
import scipy

# %% [markdown]
# Step 1: Get the data - UPDATE for our purposes

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %%
# doubt we will need...
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

# %%
filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

# %%
words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
words
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'whilst',
#  'the',
#  'term',
#  'is',
#  'still',
#  'used',
#  'in',
#  'a',
#  'pejorative',
#  'way',
#  'to',
#  'describe',
#  'any',
#  'act',
#  'that',
#  'used',
#  'violent',
#  'means',
#  'to',
#  'destroy',
#  'the',
#  'organization',
#  'of',
#  'society',
#  'it',
#  'has',
#  'also',
#  'been',
#  'taken',
#  'up',
#  'as',
#  'a',
#  'positive',
#  'label',
#  'by',
#  'self',
#  'defined',
#  'anarchists',
#  'the',
#  'word',
#  'anarchism',
#  'is',
#  'derived',
#  'from',
#  'the',
#  'greek',
#  'without',
#  'archons',
#  'ruler',
#  'chief',
#  'king',
#  'anarchism',
#  'as',
#  'a',
#  'political',
#  'philosophy',
#  'is',
#  'the',
#  'belief',
#  'that',
#  'rulers',
#  'are',
#  'unnecessary',
#  'and',
#  'should',
#  'be',
#  'abolished',
#  'although',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'what',
#  'this',
#  'means',
#  'anarchism',
#  'also',
#  'refers',
#  'to',
#  'related',
#  'social',
#  'movements',
#  'that',
#  'advocate',
#  'the',
#  'elimination',
#  'of',
#  'authoritarian',
#  'institutions',
#  'particularly',
#  'the',
#  'state',
#  'the',
#  'word',
#  'anarchy',
#  'as',
#  'most',
#  'anarchists',
#  'use',
#  'it',
#  'does',
#  'not',
#  'imply',
#  'chaos',
#  'nihilism',
#  'or',
#  'anomie',
#  'but',
#  'rather',
#  'a',
#  'harmonious',
#  'anti',
#  'authoritarian',
#  'society',
#  'in',
#  'place',
#  'of',
#  'what',
#  'are',
#  'regarded',
#  'as',
#  'authoritarian',
#  'political',
#  'structures',
#  'and',
#  'coercive',
#  'economic',
#  'institutions',
#  'anarchists',
#  'advocate',
#  'social',
#  'relations',
#  'based',
#  'upon',
#  'voluntary',
#  'association',
#  'of',
#  'autonomous',
#  'individuals',
#  'mutual',
#  'aid',
#  'and',
#  'self',
#  'governance',
#  'while',
#  'anarchism',
#  'is',
#  'most',
#  'easily',
#  'defined',
#  'by',
#  'what',
#  'it',
#  'is',
#  'against',
#  'anarchists',
#  'also',
#  'offer',
#  'positive',
#  'visions',
#  'of',
#  'what',
#  'they',
#  'believe',
#  'to',
#  'be',
#  'a',
#  'truly',
#  'free',
#  'society',
#  'however',
#  'ideas',
#  'about',
#  'how',
#  'an',
#  'anarchist',
#  'society',
#  'might',
#  'work',
#  'vary',
#  'considerably',
#  'especially',
#  'with',
#  'respect',
#  'to',
#  'economics',
#  'there',
#  'is',
#  'also',
#  'disagreement',
#  'about',
#  'how',
#  'a',
#  'free',
#  'society',
#  'might',
#  'be',
#  'brought',
#  'about',
#  'origins',
#  'and',
#  'predecessors',
#  'kropotkin',
#  'and',
#  'others',
#  'argue',
#  'that',
#  'before',
#  'recorded',
#  'history',
#  'human',
#  'society',
#  'was',
#  'organized',
#  'on',
#  'anarchist',
#  'principles',
#  'most',
#  'anthropologists',
#  'follow',
#  'kropotkin',
#  'and',
#  'engels',
#  'in',
#  'believing',
#  'that',
#  'hunter',
#  'gatherer',
#  'bands',
#  'were',
#  'egalitarian',
#  'and',
#  'lacked',
#  'division',
#  'of',
#  'labour',
#  'accumulated',
#  'wealth',
#  'or',
#  'decreed',
#  'law',
#  'and',
#  'had',
#  'equal',
#  'access',
#  'to',
#  'resources',
#  'william',
#  'godwin',
#  'anarchists',
#  'including',
#  'the',
#  'the',
#  'anarchy',
#  'organisation',
#  'and',
#  'rothbard',
#  'find',
#  'anarchist',
#  'attitudes',
#  'in',
#  'taoism',
#  'from',
#  'ancient',
#  'china',
#  'kropotkin',
#  'found',
#  'similar',
#  'ideas',
#  'in',
#  'stoic',
#  'zeno',
#  'of',
#  'citium',
#  'according',
#  'to',
#  'kropotkin',
#  'zeno',
#  'repudiated',
#  'the',
#  'omnipotence',
#  'of',
#  'the',
#  'state',
#  'its',
#  'intervention',
#  'and',
#  'regimentation',
#  'and',
#  'proclaimed',
#  'the',
#  'sovereignty',
#  'of',
#  'the',
#  'moral',
#  'law',
#  'of',
#  'the',
#  'individual',
#  'the',
#  'anabaptists',
#  'of',
#  'one',
#  'six',
#  'th',
#  'century',
#  'europe',
#  'are',
#  'sometimes',
#  'considered',
#  'to',
#  'be',
#  'religious',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'bertrand',
#  'russell',
#  'in',
#  'his',
#  'history',
#  'of',
#  'western',
#  'philosophy',
#  'writes',
#  'that',
#  'the',
#  'anabaptists',
#  'repudiated',
#  'all',
#  'law',
#  'since',
#  'they',
#  'held',
#  'that',
#  'the',
#  'good',
#  'man',
#  'will',
#  'be',
#  'guided',
#  'at',
#  'every',
#  'moment',
#  'by',
#  'the',
#  'holy',
#  'spirit',
#  'from',
#  'this',
#  'premise',
#  'they',
#  'arrive',
#  'at',
#  'communism',
#  'the',
#  'diggers',
#  'or',
#  'true',
#  'levellers',
#  'were',
#  'an',
#  'early',
#  'communistic',
#  'movement',
#  'during',
#  'the',
#  'time',
#  'of',
#  'the',
#  'english',
#  'civil',
#  'war',
#  'and',
#  'are',
#  'considered',
#  'by',
#  'some',
#  'as',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'in',
#  'the',
#  'modern',
#  'era',
#  'the',
#  'first',
#  'to',
#  'use',
#  'the',
#  'term',
#  'to',
#  'mean',
#  'something',
#  'other',
#  'than',
#  'chaos',
#  'was',
#  'louis',
#  'armand',
#  'baron',
#  'de',
#  'lahontan',
#  'in',
#  'his',
#  'nouveaux',
#  'voyages',
#  'dans',
#  'l',
#  'am',
#  'rique',
#  'septentrionale',
#  'one',
#  'seven',
#  'zero',
#  'three',
#  'where',
#  'he',
#  'described',
#  'the',
#  'indigenous',
#  'american',
#  'society',
#  'which',
#  'had',
#  'no',
#  'state',
#  'laws',
#  'prisons',
#  'priests',
#  'or',
#  'private',
#  'property',
#  'as',
#  'being',
#  'in',
#  'anarchy',
#  'russell',
#  'means',
#  'a',
#  'libertarian',
#  'and',
#  'leader',
#  'in',
#  'the',
#  'american',
#  'indian',
#  'movement',
#  'has',
#  'repeatedly',
#  'stated',
#  'that',
#  'he',
#  'is',
#  'an',
#  'anarchist',
#  'and',
#  'so',
#  'are',
#  'all',
#  'his',
#  'ancestors',
#  'in',
#  'one',
#  'seven',
#  'nine',
#  'three',
#  'in',
#  'the',
#  'thick',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'william',
#  'godwin',
#  'published',
#  'an',
#  'enquiry',
#  'concerning',
#  'political',
#  'justice',
#  'although',
#  'godwin',
#  'did',
#  'not',
#  'use',
#  'the',
#  'word',
#  'anarchism',
#  'many',
#  'later',
#  'anarchists',
#  'have',
#  'regarded',
#  'this',
#  'book',
#  'as',
#  'the',
#  'first',
#  'major',
#  'anarchist',
#  'text',
#  'and',
#  'godwin',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'philosophical',
#  'anarchism',
#  'but',
#  'at',
#  'this',
#  'point',
#  'no',
#  'anarchist',
#  'movement',
#  'yet',
#  'existed',
#  'and',
#  'the',
#  'term',
#  'anarchiste',
#  'was',
#  'known',
#  'mainly',
#  'as',
#  'an',
#  'insult',
#  'hurled',
#  'by',
#  'the',
#  'bourgeois',
#  'girondins',
#  'at',
#  'more',
#  'radical',
#  'elements',
#  'in',
#  'the',
#  'french',
#  'revolution',
#  'the',
#  'first',
#  'self',
#  'labelled',
#  'anarchist',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'it',
#  'is',
#  'commonly',
#  'held',
#  'that',
#  'it',
#  'wasn',
#  't',
#  'until',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'published',
#  'what',
#  'is',
#  'property',
#  'in',
#  'one',
#  'eight',
#  'four',
#  'zero',
#  'that',
#  'the',
#  'term',
#  'anarchist',
#  'was',
#  'adopted',
#  'as',
#  'a',
#  'self',
#  'description',
#  'it',
#  'is',
#  'for',
#  'this',
#  'reason',
#  'that',
#  'some',
#  'claim',
#  'proudhon',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'modern',
#  'anarchist',
#  'theory',
#  'in',
#  'what',
#  'is',
#  'property',
#  'proudhon',
#  'answers',
#  'with',
#  'the',
#  'famous',
#  'accusation',
#  'property',
#  'is',
#  'theft',
#  'in',
#  'this',
#  'work',
#  'he',
#  'opposed',
#  'the',
#  'institution',
#  'of',
#  'decreed',
#  'property',
#  'propri',
#  't',
#  'where',
#  'owners',
#  'have',
#  'complete',
#  'rights',
#  'to',
#  'use',
#  'and',
#  'abuse',
#  'their',
#  'property',
#  'as',
#  'they',
#  'wish',
#  'such',
#  'as',
#  'exploiting',
#  'workers',
#  'for',
#  'profit',
#  'in',
#  'its',
#  'place',
#  'proudhon',
#  'supported',
#  'what',
#  'he',
#  'called',
#  'possession',
#  'individuals',
#  'can',
#  'have',
#  'limited',
#  'rights',
#  'to',
#  'use',
#  'resources',
#  'capital',
#  'and',
#  'goods',
#  'in',
#  'accordance',
#  'with',
#  'principles',
#  'of',
#  'equality',
#  'and',
#  'justice',
#  'proudhon',
#  's',
#  'vision',
#  'of',
#  'anarchy',
#  'which',
#  'he',
#  'called',
#  'mutualism',
#  'mutuellisme',
#  'involved',
#  'an',
#  'exchange',
#  'economy',
#  'where',
#  'individuals',
#  'and',
#  'groups',
#  'could',
#  'trade',
#  'the',
#  'products',
#  'of',
#  'their',
#  'labor',
#  'using',
#  'labor',
#  'notes',
#  'which',
#  'represented',
#  'the',
#  'amount',
#  'of',
#  'working',
#  'time',
#  'involved',
#  'in',
#  'production',
#  'this',
#  'would',
#  'ensure',
#  'that',
#  'no',
#  'one',
#  'would',
#  'profit',
#  'from',
#  'the',
#  'labor',
#  'of',
#  'others',
#  'workers',
#  'could',
#  'freely',
#  'join',
#  'together',
#  'in',
#  'co',
#  'operative',
#  'workshops',
#  'an',
#  'interest',
#  'free',
#  'bank',
#  'would',
#  'be',
#  'set',
#  'up',
#  'to',
#  'provide',
#  'everyone',
#  'with',
#  'access',
#  'to',
#  'the',
#  'means',
#  'of',
#  'production',
#  'proudhon',
#  's',
#  'ideas',
#  'were',
#  'influential',
#  'within',
#  'french',
#  'working',
#  'class',
#  'movements',
#  'and',
#  'his',
#  'followers',
#  'were',
#  'active',
#  'in',
#  'the',
#  'revolution',
#  'of',
#  'one',
#  'eight',
#  'four',
#  'eight',
#  'in',
#  'france',
#  'proudhon',
#  's',
#  'philosophy',
#  'of',
#  'property',
#  'is',
#  'complex',
#  'it',
#  'was',
#  'developed',
#  'in',
#  'a',
#  'number',
#  'of',
#  'works',
#  'over',
#  'his',
#  'lifetime',
#  'and',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'some',
#  'of',
#  'his',
#  'ideas',
#  'for',
#  'more',
#  'detailed',
#  'discussion',
#  'see',
#  'here',
#  'max',
#  'stirner',
#  's',
#  'egoism',
#  'in',
#  'his',
#  'the',
#  'ego',
#  'and',
#  'its',
#  'own',
#  'stirner',
#  'argued',
#  'that',
#  'most',
#  'commonly',
#  'accepted',
#  'social',
#  'institutions',
#  'including',
#  'the',
#  'notion',
#  'of',
#  'state',
#  'property',
#  'as',
#  'a',
#  'right',
#  'natural',
#  'rights',
#  'in',
#  'general',
#  'and',
#  'the',
#  'very',
#  'notion',
#  'of',
#  'society',
#  'were',
#  'mere',
#  'illusions',
#  'or',
#  'ghosts',
#  'in',
#  'the',
#  'mind',
#  'saying',
#  'of',
#  'society',
#  'that',
#  'the',
#  'individuals',
#  'are',
#  'its',
#  'reality',
#  'he',
#  'advocated',
#  'egoism',
#  'and',
#  'a',
#  'form',
#  'of',
#  'amoralism',
#  'in',
#  'which',
#  'individuals',
#  'would',
#  'unite',
#  'in',
#  'associations',
#  'of',
#  'egoists',
#  'only',
#  'when',
#  'it',
#  'was',
#  'in',
#  'their',
#  'self',
#  'interest',
#  'to',
#  'do',
#  'so',
#  'for',
#  'him',
#  'property',
#  'simply',
#  'comes',
#  'about',
#  'through',
#  'might',
#  'whoever',
#  'knows',
#  'how',
#  'to',
#  'take',
#  'to',
#  'defend',
#  'the',
#  'thing',
#  'to',
#  'him',
#  'belongs',
#  'property',
#  'and',
#  'what',
#  'i',
#  'have',
#  'in',
#  'my',
#  'power',
#  'that',
#  'is',
#  'my',
#  'own',
#  'so',
#  'long',
#  'as',
#  'i',
#  'assert',
#  'myself',
#  'as',
#  'holder',
#  'i',
#  'am',
#  'the',
#  'proprietor',
#  'of',
#  'the',
#  'thing',
#  'stirner',
#  'never',
#  'called',
#  'himself',
#  'an',
#  'anarchist',
#  'he',
#  'accepted',
#  'only',
#  'the',
#  'label',
#  'egoist',
#  'nevertheless',
#  'his',
#  'ideas',
#  'were',
#  'influential',
#  'on',
#  'many',
#  'individualistically',
#  'inclined',
#  'anarchists',
#  'although',
#  'interpretations',
#  'of',
#  'his',
#  'thought',
#  'are',
#  'diverse',
#  ...]

# %%
np.shape(words)
# Out:
# (17005207,)

# %%
type(words)
# Out:
# list

# %% [markdown]
# Notes: So in our case, we will need to make each document a list of words with a corresponding rank?

# %% [markdown]
# Step 2: Build the dictionary and replace rare words with UNK token. DO WE STILL WANT UNK TOKEN?

# %%
# DO WE NEED TO CHANGE?
vocabulary_size = 50000

# %%
def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data_index = 0

# %% [markdown]
# Step 3: Training batch for skip-gram model

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 5239 anarchism
# 3084 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3084 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 2 of
# 195 term -> 6 a

# %% [markdown]
# Step 4: Build and Train skip-gram model

# %%
# DO WE NEED TO CHANGE THE BATCH SIZE, VALID SIZE, VALID WINDOW, ETC
# Step 4: Build and train a skip-gram model.
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# %%
# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

# %%
graph = tf.Graph()

# %%
with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.initialize_all_variables()

# %% [markdown]
# Step 5: Training

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  258.904205322
# Nearest to about: degli, omitted, mixing, sequential, rowland, susceptible, worshippers, aviators,
# Nearest to known: pulaski, analysts, surveyor, appreciating, gdr, lleyton, rejection, hails,
# Nearest to over: graves, espousing, phrase, marin, ongoing, consort, collapsed, bradley,
# Nearest to such: airbus, groundwater, irritated, fodder, wilderness, ethically, fireballs, alex,
# Nearest to these: schemas, assyrians, spanned, berlin, generated, horowitz, nc, korchnoi,
# Nearest to not: parasite, morita, tailed, counterfeiting, hms, baresi, esdras, threatening,
# Nearest to state: safeguard, pakistan, sram, rushing, hallmarks, kathy, expropriated, pigweed,
# Nearest to i: raise, install, jewishencyclopedia, impartial, goodbye, pogo, upside, biosphere,
# Nearest to use: evaporation, disappearance, howitzer, misses, unfavorable, aux, infrared, dues,
# Nearest to the: overridden, macha, palomino, plucking, castro, cornelius, thunderbolt, airstrip,
# Nearest to so: spacewalks, harappan, struggles, brock, cken, traverses, interment, horizontal,
# Nearest to two: avoids, grapevines, regents, monotheist, hemlock, summing, myles, swollen,
# Nearest to world: scythian, bacchus, wordperfect, historic, farthest, katrina, luggage, cleese,
# Nearest to people: kournikova, processes, handfasting, blitter, relegated, semite, highwayman, changeable,
# Nearest to up: overpopulation, tarleton, intentional, hif, cadence, lethbridge, congruent, describes,
# Nearest to seven: subdisciplines, alligators, assoc, monolithic, mariano, zeit, strap, ayub,
# Average loss at step  2000 :  114.158253612
# Average loss at step  4000 :  52.4035927608
# Average loss at step  6000 :  33.2064512858
# Average loss at step  8000 :  23.5252251871
# Average loss at step  10000 :  17.69556783
# Nearest to about: UNK, mixing, austin, susceptible, neighbours, oath, dione, varies,
# Nearest to known: rejection, phi, analysts, implicit, traditional, joined, surveyor, criminal,
# Nearest to over: graves, phrase, ongoing, six, bradley, layout, indian, alien,
# Nearest to such: alex, victoriae, june, specialise, agave, phi, irritated, vintage,
# Nearest to these: berlin, amphibian, hearst, breakthrough, nc, round, corps, secession,
# Nearest to not: also, web, guilt, escape, spp, issues, benefits, officers,
# Nearest to state: pakistan, gland, anarchists, ha, vs, phi, psi, rushing,
# Nearest to i: raise, july, reginae, comedian, houses, tai, cities, iron,
# Nearest to use: phi, disappearance, custom, infrared, vs, victoriae, evaporation, berber,
# Nearest to the: a, UNK, one, phi, victoriae, this, vs, his,
# Nearest to so: altenberg, argued, ivb, horizontal, legally, spacewalks, ns, reflect,
# Nearest to two: one, phi, several, six, austin, vs, three, reginae,
# Nearest to world: scythian, saratoga, murchison, historic, ordering, jupiter, enjoyed, asterism,
# Nearest to people: kournikova, phi, victoriae, introduction, processes, amphibians, agave, bj,
# Nearest to up: describes, linebackers, tarleton, intentional, psi, lethbridge, cadence, sons,
# Nearest to seven: nine, hinder, vs, reginae, victoriae, zero, agave, six,
# Average loss at step  12000 :  14.063437068
# Average loss at step  14000 :  11.8884639686
# Average loss at step  16000 :  9.76632792199
# Average loss at step  18000 :  8.58919783533
# Average loss at step  20000 :  7.82892931247
# Nearest to about: mixing, eight, six, two, UNK, neighbours, and, dione,
# Nearest to known: a, analysts, surveyor, motivational, traditional, dasyprocta, rejection, implicit,
# Nearest to over: graves, phrase, six, agouti, chilean, layout, indian, is,
# Nearest to such: alex, victoriae, specialise, agouti, june, irritated, craft, started,
# Nearest to these: berlin, amphibian, the, prevalence, corps, breakthrough, hearst, trials,
# Nearest to not: also, we, hello, auxerre, web, to, antiquated, escape,
# Nearest to state: safeguard, pigweed, pakistan, anarchists, gland, ha, phi, psi,
# Nearest to i: raise, hello, eight, comedian, houses, upside, operatorname, armenia,
# Nearest to use: phi, custom, imran, infrared, disappearance, dasyprocta, evaporation, apatosaurus,
# Nearest to the: a, his, its, their, agouti, one, this, an,
# Nearest to so: agouti, ivb, argued, legally, spacewalks, struggles, roller, altenberg,
# Nearest to two: three, one, eight, six, five, four, nine, zero,
# Nearest to world: absalom, scythian, agouti, saratoga, hebrews, ordering, maternal, historic,
# Nearest to people: kournikova, phi, victoriae, introduction, agouti, processes, km, bj,
# Nearest to up: gst, describes, linebackers, tarleton, intentional, sons, bam, cadence,
# Nearest to seven: nine, eight, zero, six, four, three, five, two,
# Average loss at step  22000 :  7.26523818624
# Average loss at step  24000 :  6.9605446316
# Average loss at step  26000 :  6.76313050008
# Average loss at step  28000 :  6.22383515763
# Average loss at step  30000 :  6.20180351639
# Nearest to about: mixing, neighbours, degli, UNK, corrupt, eight, susceptible, six,
# Nearest to known: a, pulaski, analysts, anaheim, surveyor, motivational, zef, dasyprocta,
# Nearest to over: graves, six, phrase, agouti, chilean, by, layout, as,
# Nearest to such: alex, specialise, irritated, craft, nbs, airbus, known, pasadena,
# Nearest to these: some, many, the, reuptake, rampart, prevalence, berlin, amphibian,
# Nearest to not: also, we, it, to, hello, already, they, auxerre,
# Nearest to state: safeguard, pigweed, pakistan, anaheim, anarchists, gland, primigenius, dasyprocta,
# Nearest to i: raise, hello, comedian, install, who, eight, upside, houses,
# Nearest to use: phi, custom, infrared, imran, howitzer, evaporation, misses, primigenius,
# Nearest to the: their, its, his, a, agouti, this, victoriae, primigenius,
# Nearest to so: agouti, argued, ivb, roller, texans, were, but, discontinuities,
# Nearest to two: four, three, one, six, eight, five, seven, zero,
# Nearest to world: scythian, absalom, agouti, saratoga, aorta, ordering, hebrews, maternal,
# Nearest to people: kournikova, phi, primigenius, victoriae, introduction, agouti, bj, colonization,
# Nearest to up: gst, linebackers, describes, tarleton, intentional, shipowner, shin, bam,
# Nearest to seven: nine, eight, six, five, four, three, zero, two,
# Average loss at step  32000 :  5.83506547439
# Average loss at step  34000 :  5.86623877501
# Average loss at step  36000 :  5.67876684439
# Average loss at step  38000 :  5.24527115524
# Average loss at step  40000 :  5.47615049565
# Nearest to about: mixing, degli, neighbours, six, corrupt, seven, beads, if,
# Nearest to known: a, pulaski, analysts, gdr, such, motivational, surveyor, anaheim,
# Nearest to over: graves, six, chilean, agouti, phrase, four, layout, albury,
# Nearest to such: well, alex, irritated, craft, chairmen, known, pasadena, airbus,
# Nearest to these: many, some, the, prevalence, trials, reuptake, rampart, there,
# Nearest to not: also, we, it, they, already, hello, to, antiquated,
# Nearest to state: safeguard, pigweed, pakistan, anaheim, gland, anarchists, primigenius, new,
# Nearest to i: biosphere, raise, hello, install, they, comedian, who, he,
# Nearest to use: phi, imran, infrared, custom, howitzer, misses, primigenius, evaporation,
# Nearest to the: his, their, its, a, agouti, victoriae, this, recitative,
# Nearest to so: but, cken, ivb, agouti, argued, roller, were, texans,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to world: scythian, absalom, agouti, recitative, aorta, hebrews, ordering, saratoga,
# Nearest to people: kournikova, phi, primigenius, victoriae, agouti, recitative, bj, introduction,
# Nearest to up: gst, linebackers, tarleton, describes, shin, intentional, shipowner, bam,
# Nearest to seven: eight, six, five, four, nine, three, zero, one,
# Average loss at step  42000 :  5.34907143569
# Average loss at step  44000 :  5.28970832121
# Average loss at step  46000 :  5.2663599695
# Average loss at step  48000 :  5.0287552352
# Average loss at step  50000 :  5.19214685929
# Nearest to about: mixing, degli, neighbours, seven, six, corrupt, only, asl,
# Nearest to known: pulaski, analysts, such, gdr, a, motivational, used, well,
# Nearest to over: graves, chilean, four, six, phrase, agouti, three, eight,
# Nearest to such: well, irritated, known, craft, alex, chairmen, many, specialise,
# Nearest to these: some, many, trials, prevalence, rampart, there, reuptake, other,
# Nearest to not: also, we, it, they, already, still, auxerre, hello,
# Nearest to state: safeguard, pigweed, pakistan, gland, anaheim, anarchists, new, sacked,
# Nearest to i: they, biosphere, who, t, install, raise, UNK, comedian,
# Nearest to use: phi, imran, custom, howitzer, primigenius, infrared, thibetanus, misses,
# Nearest to the: their, its, thibetanus, his, this, agouti, a, recitative,
# Nearest to so: but, ivb, cken, agouti, roller, argued, texans, were,
# Nearest to two: three, one, four, six, five, eight, seven, agouti,
# Nearest to world: scythian, absalom, aorta, agouti, hebrews, recitative, maternal, bacchus,
# Nearest to people: kournikova, phi, covalent, victoriae, agouti, primigenius, recitative, introduction,
# Nearest to up: gst, linebackers, him, shin, tarleton, intentional, describes, batavians,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Average loss at step  52000 :  5.16632210982
# Average loss at step  54000 :  5.14300871611
# Average loss at step  56000 :  5.04710226011
# Average loss at step  58000 :  5.14030842757
# Average loss at step  60000 :  4.94990417862
# Nearest to about: mixing, degli, neighbours, six, only, corrupt, tamarin, callithrix,
# Nearest to known: such, analysts, used, motivational, gdr, pulaski, a, well,
# Nearest to over: michelob, chilean, graves, six, cebus, in, agouti, phrase,
# Nearest to such: well, many, irritated, known, pasadena, craft, specialise, some,
# Nearest to these: some, many, microsite, other, the, there, trials, rampart,
# Nearest to not: also, we, it, they, to, still, callithrix, cebus,
# Nearest to state: pigweed, safeguard, gland, callithrix, anaheim, pakistan, barricade, anarchists,
# Nearest to i: they, biosphere, t, UNK, install, who, roddick, hello,
# Nearest to use: phi, tamarin, microcebus, custom, imran, callithrix, howitzer, microsite,
# Nearest to the: their, its, michelob, agouti, thibetanus, this, recitative, callithrix,
# Nearest to so: but, ivb, cken, agouti, argued, roller, tamarin, flexible,
# Nearest to two: three, four, six, one, five, seven, eight, callithrix,
# Nearest to world: scythian, tamarin, absalom, agouti, aorta, wartime, callithrix, recitative,
# Nearest to people: kournikova, callithrix, covalent, ics, phi, recitative, victoriae, agouti,
# Nearest to up: gst, him, linebackers, shin, describes, batavians, cadence, tarleton,
# Nearest to seven: six, eight, five, nine, four, three, zero, one,
# Average loss at step  62000 :  4.80748965549
# Average loss at step  64000 :  4.79930171001
# Average loss at step  66000 :  4.97934693193
# Average loss at step  68000 :  4.92312314022
# Average loss at step  70000 :  4.77803017771
# Nearest to about: mixing, neighbours, degli, only, six, tamarin, asl, cebus,
# Nearest to known: such, used, analysts, well, motivational, gdr, pulaski, defined,
# Nearest to over: michelob, chilean, graves, cebus, agouti, callithrix, tamarin, three,
# Nearest to such: well, many, known, irritated, some, these, pasadena, specialise,
# Nearest to these: some, many, other, microsite, there, rampart, which, all,
# Nearest to not: also, we, still, it, they, usually, already, callithrix,
# Nearest to state: pigweed, safeguard, gland, anaheim, callithrix, almighty, pakistan, anarchists,
# Nearest to i: they, t, biosphere, hello, who, onset, install, penh,
# Nearest to use: phi, tamarin, microcebus, callithrix, custom, imran, victoriae, primigenius,
# Nearest to the: its, their, this, michelob, agouti, thibetanus, his, dinar,
# Nearest to so: but, ivb, cken, roller, texans, argued, agouti, flexible,
# Nearest to two: three, six, one, four, five, seven, eight, callithrix,
# Nearest to world: scythian, tamarin, absalom, aorta, wartime, agouti, hebrews, callithrix,
# Nearest to people: kournikova, callithrix, ics, covalent, phi, recitative, victoriae, handy,
# Nearest to up: gst, him, linebackers, shin, batavians, cadence, tarleton, ssbn,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Average loss at step  72000 :  4.80995489657
# Average loss at step  74000 :  4.7747659421
# Average loss at step  76000 :  4.87390091497
# Average loss at step  78000 :  4.80463812029
# Average loss at step  80000 :  4.80628853738
# Nearest to about: mixing, degli, neighbours, only, asl, corrupt, seven, tamarin,
# Nearest to known: used, such, defined, well, motivational, gdr, analysts, seen,
# Nearest to over: michelob, graves, chilean, cebus, callithrix, tamarin, agouti, in,
# Nearest to such: well, many, these, known, irritated, some, pasadena, committing,
# Nearest to these: some, many, other, there, which, such, all, microsite,
# Nearest to not: we, still, it, they, also, usually, already, be,
# Nearest to state: vec, anaheim, gland, safeguard, pigweed, new, almighty, callithrix,
# Nearest to i: t, they, biosphere, you, onset, roddick, install, who,
# Nearest to use: phi, tamarin, microcebus, victoriae, callithrix, imran, custom, primigenius,
# Nearest to the: its, michelob, their, thibetanus, agouti, recitative, callithrix, dinar,
# Nearest to so: but, ivb, roller, cken, agouti, flexible, texans, argued,
# Nearest to two: three, six, four, five, seven, one, eight, callithrix,
# Nearest to world: scythian, tamarin, wartime, aorta, absalom, agouti, iit, hebrews,
# Nearest to people: kournikova, callithrix, ics, phi, recitative, agouti, handy, victoriae,
# Nearest to up: gst, him, linebackers, shin, tarleton, batavians, kilobit, concerned,
# Nearest to seven: six, five, eight, four, nine, three, zero, two,
# Average loss at step  82000 :  4.80608620894
# Average loss at step  84000 :  4.78668550408
# Average loss at step  86000 :  4.74622099447
# Average loss at step  88000 :  4.68850937116
# Average loss at step  90000 :  4.75427961612
# Nearest to about: mixing, degli, neighbours, only, corrupt, asl, approximately, three,
# Nearest to known: used, such, defined, well, seen, motivational, gdr, tasman,
# Nearest to over: michelob, graves, chilean, cebus, five, tamarin, callithrix, agouti,
# Nearest to such: well, many, these, known, some, irritated, committing, like,
# Nearest to these: some, many, which, such, several, there, all, other,
# Nearest to not: we, they, still, it, also, usually, already, never,
# Nearest to state: vec, anaheim, safeguard, pigweed, gland, almighty, cegep, callithrix,
# Nearest to i: t, they, you, we, UNK, who, ii, onset,
# Nearest to use: phi, tamarin, microcebus, callithrix, victoriae, imran, primigenius, custom,
# Nearest to the: their, its, thibetanus, michelob, agouti, his, callithrix, tamarin,
# Nearest to so: roller, ivb, but, texans, flexible, while, argued, tamarin,
# Nearest to two: three, four, five, six, seven, one, eight, callithrix,
# Nearest to world: scythian, tamarin, wartime, aorta, agouti, absalom, iit, wordperfect,
# Nearest to people: kournikova, callithrix, ics, handy, agouti, recitative, calculated, phi,
# Nearest to up: gst, him, shin, linebackers, off, batavians, kilobit, tarleton,
# Nearest to seven: six, eight, five, four, nine, three, zero, one,
# Average loss at step  92000 :  4.71727903461
# Average loss at step  94000 :  4.61417955351
# Average loss at step  96000 :  4.72997922027
# Average loss at step  98000 :  4.62522789913
# Average loss at step  100000 :  4.67744375694
# Nearest to about: only, mixing, neighbours, degli, asl, corrupt, on, approximately,
# Nearest to known: used, such, defined, well, seen, gdr, regarded, motivational,
# Nearest to over: three, michelob, graves, chilean, cebus, through, four, tamarin,
# Nearest to such: many, known, well, these, some, irritated, pasadena, committing,
# Nearest to these: some, many, several, all, which, such, other, their,
# Nearest to not: still, they, never, we, usually, also, be, often,
# Nearest to state: eurocents, vec, anaheim, pigweed, sram, gland, safeguard, cegep,
# Nearest to i: you, t, they, we, biosphere, ii, who, onset,
# Nearest to use: tamarin, phi, microcebus, victoriae, callithrix, inquisitors, imran, primigenius,
# Nearest to the: its, their, michelob, thibetanus, agouti, his, recitative, tamarin,
# Nearest to so: ivb, but, roller, texans, flexible, argued, while, agouti,
# Nearest to two: three, four, five, six, seven, one, callithrix, eight,
# Nearest to world: scythian, aorta, wartime, tamarin, wordperfect, customize, devolved, agouti,
# Nearest to people: callithrix, kournikova, agouti, handy, calculated, recitative, ics, victoriae,
# Nearest to up: him, gst, off, shin, out, linebackers, them, batavians,
# Nearest to seven: six, eight, five, four, nine, three, zero, callithrix,

# %%
final_embeddings
# Out:
# array([[ 0.0455975 , -0.09366986,  0.10564441, ..., -0.07698934,
#          0.1146199 , -0.13748007],
#        [ 0.15954442,  0.02697963,  0.02189093, ..., -0.09380219,
#          0.03770462, -0.06978144],
#        [-0.12643866, -0.00368863,  0.13828219, ..., -0.05057281,
#          0.03901852, -0.12910505],
#        ...,
#        [ 0.0559676 ,  0.01892968,  0.01437467, ...,  0.09161534,
#         -0.08942407, -0.17549412],
#        [-0.08138949,  0.06890856, -0.09526756, ...,  0.01506946,
#         -0.01207101, -0.07473588],
#        [ 0.1224125 , -0.13074549, -0.0059563 , ...,  0.08468792,
#          0.05524575, -0.01435839]], dtype=float32)

# %%
np.shape(final_embeddings)
# Out:
# (50000, 128)

# %% [markdown]
# Note: So now our input to the CNN will be an array with shape: vocabulary size x embedding size. These are parameters we choose - how to pick the optimal for our raw data?

# %% [markdown]
# Step 6: Visualize

# %%
# Step 6: Visualize the embeddings.
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
